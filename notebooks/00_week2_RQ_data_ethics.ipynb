# %% [markdown]
# # Research Question, Dataset, and Ethics Check
#
# Use this notebook to document three things for your proposed research project:
#
# 1. Your research question
# 2. The dataset you plan to use
# 3. The ethical aspects you have considered
#
# > Do not load or analyse the data in this notebook. Choose a dataset, provide a reliable reference link, explain why you chose it, and answer the ethics questions using the dataset documentation and any relevant research literature. If a question is not applicable, write N/A and explain why.
#
# ## 1. Research Question
#
# - **Main research question:** [Write clear, focused questions that can be investigated using data.]
# - **Why is this question interesting or important?** [Write one or two sentences.]
# - **Who might use or care about the answer?** [Identify relevant people, communities, organisations, or decision-makers.]
# - **Possible sub-questions:** [List any smaller questions that help answer the main question.]
#
# ## 2. Dataset Reference
#
# - **Dataset name:** [ADD DATASET NAME]
# - **Source link:** [ADD URL, DOI, catalogue entry, or other reliable reference]
# - **Date accessed:** [YYYY-MM-DD]
# - **Who published or collected it?** [ADD PERSON, ORGANISATION, or UNKNOWN]
# - **Why did you choose this dataset?** [Write one or two sentences explaining how it relates to your research question and why it is suitable.]
# - **Evidence or notes:** [Add links, citations, or brief notes that support your choice.]

# %% [markdown]
# 1. Research Question: Can different openings predict who wins a chess game, for different ratings and/or game types?
# - This can beneficial for those wanting to learn chess to see which openings too use. We're also all interested in chess and would like to analyse different opening to improve our own game.
# - As mentioned above we would be interested in the results, along with beginners. Aswell anyone with a gneeraly interest in chess might find our results interesting.
# Sub Questions
# - Which type of openings normally win a specific type of game?
# - Do higher rated players have longer games?
# - Do higher rated players play longer/more complex openings?
#
# 2.
# Dataset Name: Chess Game Dataset (Lichess)
# Reference: https://www.kaggle.com/datasets/datasnaek/chess
# Date Accesses: 14/09/26
# Published by: Mitchell J, Software engineer, University of Glasgow graduate.
# Reason for selection: We chose this data as it contained the right information we were looking for, i.e. Opening names, game length, times and increments of the match and winner. It also contined additional informtion we can use to futher our analysis like player ratings. It was also in csv format which is very easy to work with in excel and then transfer to other software.

# %% [markdown]
# ## Research Questions and Answers
#
# For every answer, distinguish between **known evidence**, **reasonable interpretation**, and **unknown information to investigate**.
#
# ### 1. Where did the data come from?
#
# **Answer:** [Describe the original source, collection method, owner, URL/DOI, and date accessed. Cite evidence where possible.]
#
# ### 2. Why was it originally collected?
#
# **Answer:** [State the original purpose. If the current project uses it for a different purpose, explain that change and whether it is ethically justified.]
#
# ### 3. Who is represented?
#
# **Answer:** [Describe the population, groups, locations, time period, and sampling frame represented by the data.]
#
# ### 4. Who might be missing?
#
# **Answer:** [Identify groups excluded by the sampling method, missing responses, access barriers, non-response, or incomplete records.]
#
# ### 5. What personal or sensitive information does it contain, explicitly or implicitly?
#
# **Answer:** [List direct identifiers and sensitive fields. Also identify combinations of fields that could identify people or act as proxies for sensitive attributes.]
#
# ### 6. What could your analysis reveal that was not obvious in the original data?
#
# **Answer:** [Describe possible inferences, correlations, predictions, re-identification risks, or conclusions about individuals or groups.]
#
# ### 7. Who could benefit from your findings?
#
# **Answer:** [Identify the people, communities, organisations, or decision-makers who could benefit, and explain how.]
#
# ### 8. Who could be harmed or misrepresented?
#
# **Answer:** [Identify people or groups who could experience privacy loss, discrimination, stigma, exclusion, incorrect decisions, or misleading representation.]

# %% [markdown]
# 1. Our data comes from Kaggle. It was uploaded my a "Mitchell J" and according to his profile he is a software engineer and computer scienc graduate from glasgow university. He collected it useing Lichess API whichc allows you to collect a users game history. This is publicly available data and seems to be the most common way these sort of data sets are collected (The 4 most used chess game datasets on Kaggle were collected this way)
# https://www.kaggle.com/datasets/datasnaek/chess
#
# 2. The owner dosnen't state a reason for the collection of this data. He does however provide a paragraph on some of the possible uses it might have. therefore it could be reasonaly interpretted that this data was uploaded for the benefit of other researchers and university students such as ourselves who are looking for easily accessible data.
#
# 3. Userers of Lichess.org are represented in this sample.
#
# 4. People who use other chess sites are excluded from this sample. Mitchell also states that in order to get this data he needed the user name of people on Lichess. It does however let you select all the usernames of people on a team which is what was done, with mitchell stating he took several teams with over 1500 members.
#
# 5. Usernames are present in our data along with start and end times. (Its not clear what start and endtimes represent althought I doubt there accuracy as the start and end times of games as for multiple long games these values are the same)
#
# 6. Which types of openings win specific types of games, i.e. Buller, blitz or classical matches.
# Which openings lead to longer games?
# Are specific openings more frequent among higher rated players?
# The likelihood of someone to win based off their rating.
#
# 7. Beginners to chess as it could be a simple way to compare openings to their winning percentages.
# Other chess enthusiasts interested in seeing results such as these
#
# 8. There isn't really any ethical issues with our data that could have a serious impact on individualls. However are data could be misrepresented as it only contains user of Lichess.org. If Lichess was affected by any other factors that affected what users youse if we wouldnt be able to see that in our data.
